# %%
#!pip install selenium

# %%
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(30) #set timeout

# %%
driver.get('https://shopee.co.th/')

# %%
select_thai = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')
select_thai.click()
# Out:
# C:\Users\Chanawee\AppData\Local\Temp\ipykernel_53152\3927697875.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   select_thai = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div/div[3]/div[1]/button')

# %%
close_popup = driver.execute_script('return document.querySelector("shopee-banner-popup-stateful").shadowRoot.querySelector("div.shopee-popup__close-btn")')
close_popup.click()

# %%
# time.sleep(2)
searchbar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')
# Out:
# C:\Users\Chanawee\AppData\Local\Temp\ipykernel_53152\260028.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   searchbar = driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div[2]/div/div[1]/div[1]/div/form/input')

# %%
searchbar.send_keys('น้ำหอม') #to search somethimg change this string

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
searchbar.send_keys(Keys.ENTER)

# %%
time.sleep(0.5)
driver.execute_script("document.body.style.zoom='10%'")
time.sleep(4)
sort = driver.find_element(By.XPATH,"//div[text()='สินค้าขายดี']")
driver.execute_script("arguments[0].click();", sort)

# %%
time.sleep(7)
data = driver.page_source
import bs4
soup = bs4.BeautifulSoup(data)

# %%
product_name = soup.find_all('div',{'class':'_10Wbs- _2STCsK _3IqNCf'})

# %%
product_name_list = []
for product in product_name :
    product_name_list.append(product.text)
len(product_name_list)

for i in range(5):
    product_name_list.pop(0)
    product_name_list.pop()
product_name_list #correction check
# Out:
# ['kingshopping สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664',
#  'YOTAI สเปย์การ์ด 20ml ใส่น้ำหอม เเอลกอฮอล์ ขวดสเปรย์ พกพาสะดวก คุณภาพดี',
#  'เจลดับกลิ่นชักโครก Toilet Gel Cleaner เจลหอม ดับกลิ่นห้องน้ำ เจลทำความสะอาด เจลลดคราบ ชักโครก ห้องน้ำ น้ำยาทำความสะอาด',
#  '365mallshop ขวดสเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664',
#  'YOTAI น้ำหอม มาดามฟิน ขนาดพกพา XS---2 ml（---การจัดส่งแบบสุ่ม---）',
#  'A68 ❤️ 1 ฿ เท่านั้น ❤️ถุงหอม ถุงปรับอากาศ ใส่ไว้ที่ไหนก็หอม ของแถมจีบลูกค้า พร้อมส่ง⛔️ตอนนี้ เหลือ 2 สี⛔️',
#  'GTR สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664',
#  '♥️♥️[💯% แท้]✅✅น้ำหอม 🔥🔥 ขนาดพกพา🔥🔥 2ml.จ้าา',
#  'kingshopping น้ำหอม มาดามฟิน ขนาดพกพา 2 ml. A74',
#  '【💯% แท้ 】น้ำหอม ขนาดพกพา ทดลอง 2ML',
#  'YOTAI น้ำหอม COOC ❤️ มี 3 กลิ่น พร้อมส่ง หอมติดทนนาน 50ml',
#  'ก้านน้ำหอม ก้านไม้หอมปรับอากาศ 50มล. น้ำมันหอมระเหย น้ำหอมอโรม่า น้ำมันหอมระเหย  ก้านไม้หอม (พร้อมส่ง!!)',
# ...

# %%
sell_number = soup.find_all('div',{'class':'_1uq9fs'})

# %%
sell_number_list = []
for sales in sell_number :
    sell_number_list.append(sales.text)


for i in range(5):
    sell_number_list.pop(0)
    sell_number_list.pop()
print(len(sell_number_list)) #correction check
sell_number_list
# Out:
# 50
# ['ขายได้ 45.1พัน ชิ้น/เดือน',
#  'ขายได้ 34.7พัน ชิ้น/เดือน',
#  'ขายได้ 33.3พัน ชิ้น/เดือน',
#  'ขายได้ 18พัน ชิ้น/เดือน',
#  'ขายได้ 17.6พัน ชิ้น/เดือน',
#  'ขายได้ 15.4พัน ชิ้น/เดือน',
#  'ขายได้ 14.4พัน ชิ้น/เดือน',
#  'ขายได้ 13.9พัน ชิ้น/เดือน',
#  'ขายได้ 14.2พัน ชิ้น/เดือน',
#  'ขายได้ 10.5พัน ชิ้น/เดือน',
#  'ขายได้ 11.5พัน ชิ้น/เดือน',
#  'ขายได้ 11.4พัน ชิ้น/เดือน',
#  'ขายได้ 10.1พัน ชิ้น/เดือน',
#  'ขายได้ 9.9พัน ชิ้น/เดือน',
#  'ขายได้ 9.2พัน ชิ้น/เดือน',
#  'ขายได้ 9.1พัน ชิ้น/เดือน',
#  'ขายได้ 9.1พัน ชิ้น/เดือน',
#  'ขายได้ 8.8พัน ชิ้น/เดือน',
#  'ขายได้ 8.6พัน ชิ้น/เดือน',
#  'ขายได้ 8.6พัน ชิ้น/เดือน',
#  'ขายได้ 8.4พัน ชิ้น/เดือน',
#  'ขายได้ 8.2พัน ชิ้น/เดือน',
#  'ขายได้ 7.2พัน ชิ้น/เดือน',
#  'ขายได้ 7.1พัน ชิ้น/เดือน',
#  'ขายได้ 7.1พัน ชิ้น/เดือน',
#  'ขายได้ 6.7พัน ชิ้น/เดือน',
#  'ขายได้ 6.6พัน ชิ้น/เดือน',
#  'ขายได้ 6.6พัน ชิ้น/เดือน',
#  'ขายได้ 6.5พัน ชิ้น/เดือน',
#  'ขายได้ 6.4พัน ชิ้น/เดือน',
#  'ขายได้ 8พัน ชิ้น/เดือน',
# ...

# %%
review_number_list = []

# %%
for i in range(0,50,1):#len(product_name_list)):
    product = driver.find_element(By.XPATH,"//div[.='" + product_name_list[i] + "']")
    driver.execute_script("arguments[0].click();", product)
    driver.execute_script("document.body.style.zoom='30%'")
    print(i)
    print(product_name_list[i])
    time.sleep(5)
    pageData = driver.page_source
    pageSoup = bs4.BeautifulSoup(pageData)
    review_number = pageSoup.find("div", {"class": "product-rating-overview__filter product-rating-overview__filter--with-comment"}).get_text(strip=True)
    print(review_number)
    review_number_list.append(review_number)
    driver.back()
    driver.execute_script("document.body.style.zoom='10%'")
driver.back() #done confirm
# Out:
# 0
# kingshopping สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664
# ความคิดเห็น (420)
# 1
# YOTAI สเปย์การ์ด 20ml ใส่น้ำหอม เเอลกอฮอล์ ขวดสเปรย์ พกพาสะดวก คุณภาพดี
# ความคิดเห็น (179)
# 2
# เจลดับกลิ่นชักโครก Toilet Gel Cleaner เจลหอม ดับกลิ่นห้องน้ำ เจลทำความสะอาด เจลลดคราบ ชักโครก ห้องน้ำ น้ำยาทำความสะอาด
# ความคิดเห็น (6.5พัน)
# 3
# 365mallshop ขวดสเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664
# ความคิดเห็น (26)
# 4
# YOTAI น้ำหอม มาดามฟิน ขนาดพกพา XS---2 ml（---การจัดส่งแบบสุ่ม---）
# ความคิดเห็น (677)
# 5
# A68 ❤️ 1 ฿ เท่านั้น ❤️ถุงหอม ถุงปรับอากาศ ใส่ไว้ที่ไหนก็หอม ของแถมจีบลูกค้า พร้อมส่ง⛔️ตอนนี้ เหลือ 2 สี⛔️
# ความคิดเห็น (243)
# 6
# GTR สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอลกอฮอล์ CY664
# ความคิดเห็น (38)
# 7
# ♥️♥️[💯% แท้]✅✅น้ำหอม 🔥🔥 ขนาดพกพา🔥🔥 2ml.จ้าา
# ความคิดเห็น (3.3พัน)
# 8
# kingshopping น้ำหอม มาดามฟิน ขนาดพกพา 2 ml. A74
# ความคิดเห็น (440)
# 9
# 【💯% แท้ 】น้ำหอม ขนาดพกพา ทดลอง 2ML
# ความคิดเห็น (3.7พัน)
# 10
# ...

# %%
print(review_number_list)
print(len(review_number_list))
print(len(product_name_list)) #correction check
# Out:
# ['ความคิดเห็น (420)', 'ความคิดเห็น (179)', 'ความคิดเห็น (6.5พัน)', 'ความคิดเห็น (26)', 'ความคิดเห็น (677)', 'ความคิดเห็น (243)', 'ความคิดเห็น (38)', 'ความคิดเห็น (3.3พัน)', 'ความคิดเห็น (440)', 'ความคิดเห็น (3.7พัน)', 'ความคิดเห็น (3พัน)', 'ความคิดเห็น (13.9พัน)', 'ความคิดเห็น (1พัน)', 'ความคิดเห็น (200)', 'ความคิดเห็น (278)', 'ความคิดเห็น (1.9พัน)', 'ความคิดเห็น (11.9พัน)', 'ความคิดเห็น (523)', 'ความคิดเห็น (282)', 'ความคิดเห็น (616)', 'ความคิดเห็น (527)', 'ความคิดเห็น (683)', 'ความคิดเห็น (721)', 'ความคิดเห็น (118)', 'ความคิดเห็น (1.1พัน)', 'ความคิดเห็น (530)', 'ความคิดเห็น (470)', 'ความคิดเห็น (1.8พัน)', 'ความคิดเห็น (329)', 'ความคิดเห็น (1.6พัน)', 'ความคิดเห็น (4.1พัน)', 'ความคิดเห็น (134)', 'ความคิดเห็น (589)', 'ความคิดเห็น (3.8พัน)', 'ความคิดเห็น (1.1พัน)', 'ความคิดเห็น (5.4พัน)', 'ความคิดเห็น (4.3พัน)', 'ความคิดเห็น (533)', 'ความคิดเห็น (8.8พัน)', 'ความคิดเห็น (37)', 'ความคิดเห็น (256)', 'ความคิดเห็น (37)', 'ความคิดเห็น (482)', 'ความคิดเห็น (3.6พัน)', 'ความคิดเห็น (5.2พัน)', '
# ...

# %%
# !pip install pandas
# shopee_data = shopee_data.iloc[0:0] #reset data in dataframe
print(len(product_name_list))
print(len(sell_number_list))
print(len(review_number_list))
# Out:
# 50
# 50
# 50

# %%
import pandas as pd

# %%
shopee_data = pd.DataFrame([product_name_list,sell_number_list,review_number_list])
shopee_data = shopee_data.transpose()
shopee_data.columns = ['title','sales','review']

# %%
shopee_data
# Out:
#                                                 title  \
# 0   kingshopping สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น...
# 1   YOTAI สเปย์การ์ด 20ml ใส่น้ำหอม เเอลกอฮอล์ ขวด...
# 2   เจลดับกลิ่นชักโครก Toilet Gel Cleaner เจลหอม ด...
# 3   365mallshop ขวดสเปรย์การ์ด20mlสเปรย์พบพา สเปรย...
# 4   YOTAI น้ำหอม มาดามฟิน ขนาดพกพา XS---2 ml（---กา...
# 5   A68 ❤️ 1 ฿ เท่านั้น ❤️ถุงหอม ถุงปรับอากาศ ใส่ไ...
# 6   GTR สเปรย์การ์ด20mlสเปรย์พบพา สเปรย์น้ำหอม แอล...
# 7         ♥️♥️[💯% แท้]✅✅น้ำหอม 🔥🔥 ขนาดพกพา🔥🔥 2ml.จ้าา
# 8     kingshopping น้ำหอม มาดามฟิน ขนาดพกพา 2 ml. A74
# 9                  【💯% แท้ 】น้ำหอม ขนาดพกพา ทดลอง 2ML
# 10  YOTAI น้ำหอม COOC ❤️ มี 3 กลิ่น พร้อมส่ง หอมติ...
# 11  ก้านน้ำหอม ก้านไม้หอมปรับอากาศ 50มล. น้ำมันหอม...
# 12  พร้อมส่งทันที 💥ส่ง7฿น้ำหอมแบรนด์100% มี 40 กลิ...
# 13  【A054】INITIAL LIFE🌼🌈น้ำหอมซักผ้า เม็ดน้ำหอมซัก...
# 14  OKUMI_SHOP เจลดับกลิ่นกลิ่นชักโครก ในห้องน้ำ เ...
# 15  (5บาททุกสีไม่มีขั้นต่ำ) สเปรย์การ์ด20ml-25ml ส...
# ...
